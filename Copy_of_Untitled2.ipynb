# %% [markdown]
# <a href="https://colab.research.google.com/github/khandelwalsneha029-byte/EXCEL-ASSIGNMENT/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Cleaning & Essential
# Functions
# assignment

# %% [markdown]
# 1.What is data cleaning, and why is it important in data analysis?
#
# ANSWER-Data cleaning is the process of detecting and correcting errors, inconsistebcies, duplicates,and missing values in raw dara so that it becomes accurate,consistent clean data leads leads to reliable analysis and better decsions, while dirty data produces misleading results and weakness trust in insight.
#
#  (.What are the potential consequences of analyzing unclean or messy data?
#
#    ANSWER->.Inaccurate or biased conclusions,such as wrong forecasts,incorrect trends,or misleading statistics.
#
#    .poor busniess decions and inefficient operations, including bad planning,wasted resoures,and failed marketing or targeting.
#
#    .increased costs and risks,(for example) extra time spent fixing errors later and potential legal or compliance issuesfrom incorrect records.)
#
#   (Explain the common steps involved in cleaning and organizing data?
#
#    ANSWER->(COMMON DATA CLEANING STEPS)
#
#    .Inspects data quality to find missing values,outliears,duplicate,and format issues using summaries and basic checks.
#
#    .Remove  irrelevts or dupliacte records,fix structural or formatting errors,and standardize units,categories, and data types.
#
#    .Handle missing and incorrect values(impute , correct or remove them) and then validate the cleansed dataset to ensure it is consistent and ready for analysis.)
#
#
#                          (first answer is compelete )

# %% [markdown]
# 3.Explain the use of text functions such as TRIM , LEFT, RIGHT, MID, and CONCAT in data cleaning.
#
# ANSWER-> USE OF TEXT FUCTIONS IN DATA CLEANING.
#
#         .TRIM()- REMOVES EXTRA SPACES FROM TEXT.
#         .LEFT()-EXTRACTS CHARACTERS FROM THE LEFT SIDE OF TEXT.
#         .RIGHT()-EXTRACTS CHARACTERS FROM THE RIGHT SIDE OF TEXT.
#         .MID()-EXTRACTS TEXT FROM THE MIDDLE OF A STING.
#         .CONCAT()JOINS TWO OR MORE TEXT VALUES INTO ONE.
#
#
#                          (3RD ANSWER IS COMPELETE)

# %% [markdown]
# 4. What is the role of date functions like TODAY in managing datasets?
#
#   ANSWER->Date fuctions like **TODAY**() automatically give the current date and are used to manage datesets by tracking dates,calculating durcations or ages, filtering recent data,monitoring deadlines, and keeping reports updates without manual entry.
#
#
#                         (4th answer compelete)

# %% [markdown]
#  6.Understand and apply fundamental text functions like LEFT, RIGHT, MID, and LEN.
#
# .Extract the first 5 characters from the string "ExcelTipsAreGreat" using the LEFT function.
#
# .Extract the last 4 characters from "DataAnalysis.xlsx" using the RIGHT function.
#
# .Extract the substring "Tips" from "ExcelTipsAreGreat" using the MID function.
#
# .Count the total number of characters in the string "Hello World!" using the LEN function.
#
# .Create a formula to extract the middle 6 characters from "12345-67890-ABCDE"
#
# ANSWER-> 1ST POINT
#
# .We use the **left** function to take characters from the begining of the text
#    **FORMULA**:  =**LEFT**("ExcelTipsAreGreat",5)
#
#            (**RESULTS:EXCEL**)
#
# 2 POINT>
#                                                                                 .THE **RIGHT **fuction is used to get characters from end of the text.
#      **FORMULA:**  =RIGHT("DataAnalysis.xlsx",4)
#              (RESULT: **xlxs **)
#
# 3 POINT->
#
# .The **mid** fuctions extracts text from the middle by giving a start postion and length.
#     FORMULA:
#      =**MID** ("ExcelTipsAreGreat",6,4)
#                  (RESULT: **TIPS**)
#
# 4 POINT->
#
# .The **LEN** fuctions countd all characters including spaces.
#    FORMULA:
#     =**LEN** ("Hello World!")
#     RESULTS:**12**
#
#  5 POINT->Here** MID** is used to get 6 characters starting from the 7th position.
#     FORMULA:
#       =**MID**("12345-67890-ABCDE",7,6)
#
#           RESULTS:** 67890-  **
#
#
#                           (6th answer is compelete)

# %% [markdown]
# 7 Understand how to combine text using CONCAT, TEXTJOIN, and the & operator.
#
# .Use CONCAT to combine "Hello" and "World" with a space in between.
#
# .Combine "Apple", "Banana", and "Cherry" into a single string separated by commas using TEXTJOIN.
#
#
# .Use the & operator to create the string "2025: Excel Functions" by combining "2025", ": ", and "Excel
# Functions
#
# .Create a comma-separated list from the range A1:A5 using TEXTJOIN
#
# .Combine first names in column A with last names in column B to create full names in column C
#    [link text](https://![Screenshot 2025-12-18 191911.png](data:image/png;base64,...))

# %% [markdown]
# 8  Understanding TODAY() and NOW()
#
# a. What is the difference between TODAY() and NOW() in Excel? Provide an example of when you would use
# each function.
#
# b. If cell A1 contains the date 2025-06-10, write a formula using TODAY() to determine how many days are
# left until that date
#
# c. Write an Excel formula using NOW() to display the current date and time in the format MM/DD/YYYY
# HH:MM AM/PM. ́
#
# d. If a cell contains =TODAY(), what will happen when the worksheet is reopened the next day? Explain
#
# e. You want to store a static date (today’s date) in a cell without it changing every day. What keyboard
# shortcut should you use
# [
#      ![image.png](data:image/png;base64,...)                                   ](https://)
#                   answer8
